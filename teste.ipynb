# %%
import pandas as pd

# %%
df = pd.read_parquet("data/banco_smiles_aromatizados.parquet")
df
# Out:
#       id_Anel1  ID_Anel_Anel1 SMILES_Base_Anel1  \
# 0          319              2          C1CCCCC1
# 1         8848             45          S1SCCCC1
# 2         2142             11          C1CNCCC1
# 3         6814             35           C1CNCC1
# 4         5249             27           N1NCCC1
# ...        ...            ...               ...
# 5969       252              2          C1CCCCC1
# 5970       436              3          N1CCCCC1
# 5971       751              4          O1CCCCC1
# 5972      9254             47          O1CSCCC1
# 5973      5006             26           S1CCCC1
#
#                          SMILES_Modificado_Anel1 ID_Frag_1_Anel1  \
# 0                         C1(N)C(Br)CCC(N(C)C)C1              11
# 1               S1(C(F)(F)F)S(N(CC)CC)CC(NCC)CC1              17
# 2                    C1CN(Br)C(C(=O)OCC)C(NCC)C1              21
# 3                C1(N)CN(S(=O)(=O)O)C(NC(=O)C)C1              11
# ...
